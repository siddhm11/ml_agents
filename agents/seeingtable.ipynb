# %%
# !pip install pandas
import pandas as pd
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 7.0 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 9.5 MB/s eta 0:00:00a 0:00:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]2m3/4 [pandas]
# ...

# %%
df = pd.read_csv('preddata_with_predictions.csv')

# %%
df.head(20)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                41.0        880.0           129.0
# 1     -122.22     37.86                21.0       7099.0          1106.0
# 2     -122.24     37.85                52.0       1467.0           190.0
# 3     -117.95     33.84                18.0       3418.0           815.0
# 4     -117.94     33.83                20.0        812.0           192.0
# 5     -121.75     39.88                16.0       2867.0           559.0
# 6     -121.68     39.82                15.0       3996.0           748.0
# 7     -121.54     40.06                17.0        858.0           262.0
# 8     -121.51     39.97                22.0       1468.0           285.0
# 9     -121.59     39.86                14.0       1527.0           269.0
# 10    -121.58     39.83                16.0       4591.0           904.0
# 11    -121.60     39.80                10.0       1742.0           307.0
# ...

# %%
df.tail()
# Out:
#      longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 176    -121.97     37.54                31.0       1949.0           344.0
# 177    -121.97     37.55                17.0       4924.0          1247.0
# 178    -121.98     37.54                17.0       5133.0          1375.0
# 179    -121.99     37.55                16.0       6647.0          2098.0
# 180    -121.94     37.56                15.0       5674.0           748.0
#
#      population  households  median_income  median_house_value  \
# 176       986.0       322.0         4.6349            196200.0
# 177      3080.0      1182.0         3.1680            189400.0
# 178      3386.0      1339.0         3.1326            220800.0
# 179      4649.0      1903.0         2.9074            213800.0
# 180      2412.0       714.0         8.3996            442900.0
#
#     ocean_proximity  predicted_median_house_value
# 176       <1H OCEAN                 238792.454117
# ...

# %%
totaldiff = abs(sum(df['predicted_median_house_value'])- sum(df['median_house_value']))

# %%
totaldiff
# Out:
# 892102.0332487859

# %%
total = sum(df['median_house_value'])

# %%
totaldiff/total * 100
# Out:
# 2.8156764528074194

# %%
df2 = pd.read_csv('data-8013-trends.csv')

# %%
# Save the reduced dataset to a new CSV file
import pandas as pd

# Read the CSV file
df2 = pd.read_csv('data-8013-trends.csv')

# Reduce the dataframe to only 100,000 rows
reduced_df = df2.head(100000)

# Optional: Check the shape to confirm
print(f"Original shape: {df2.shape}")
print(f"Reduced shape: {reduced_df.shape}")

reduced_df.to_csv('data-8013-trends-reduced.csv', index=False)
# Out:
# Original shape: (823225, 15)
# Reduced shape: (100000, 15)

# %%
df2.head()
# Out:
#   BILLING_DATE  SITE  BRAND FORMAT_DESC      MH_SEGMENT       MH_FAMILY  \
# 0   2024-09-16  8013  04063      TRENDS     MENS CASUAL     WINTER WEAR
# 1   2023-08-20  8013   A423      TRENDS   PERSONAL CARE   SKIN PRODUCTS
# 2   2023-08-20  8013  02370      TRENDS     D2C Fashion             Men
# 3   2023-10-20  8013   J378      TRENDS   MENS FOOTWEAR    FW MN CASUAL
# 4   2023-10-20  8013   J380      TRENDS  FW ACCESSORIES  FW AC SHOECARE
#
#     MH_CLASS          MH_BRICK       ARTICLE  TOTAL_BILLING_QTY  \
# 0       TOPS       SWEATSHIRTS  443047006022                  1
# 1  SKIN CARE  EXFOLIANTS/MASKS     492859499                  1
# 2   Footwear      Sports Shoes  469252942003                  1
# 3       MENS       SHOE SLIPON  450154389005                  1
# 4     UNISEX            OTHERS  450150552001                  1
#
#    TOTAL_GROSS_MARGIN  TOTAL_MARKDOWN  TOTAL_NET_SALES  TOTAL_GROSS_SALES  \
# ...
